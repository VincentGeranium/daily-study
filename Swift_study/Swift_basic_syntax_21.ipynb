# %% [markdown]
# # 집단 자료형
# ## 연관된 데이터를 손쉽게 다루기
# ### 집합
# - #### 집합(Sets)는 같은 타입의 서로 다른 값을 중복 없이 저장하고자 할 때 사용하는 집단 자료형
# - #### 집합(Sets)는 배열(Array)과 매우 유사
#     - #### 그러나 배열을 사용하기에는 순서가 그다지 중요하지 않은 데이터들이거나 중복 없이 한 번만 저장되어야 하는 데이터들을 다룰 때 배열 대신 사용할 수 있는 자료형

# %% [markdown]
# - #### 집합은 내부적으로 해시(Hash) 연산의 결과값을 이용하여 데이터를 저장하므로 집합에 저장할 데이터 타입은 해시 연산을 할 수 있는 타입이어야 한다
#     - #### 다시 말해 집합에 저장할 데이터 타입은 반드시 해시값을 계산하는 방법을 제공해야 한다는 뜻이다.
# - #### 해시 연산의 결과로 얻을 수 있는 해시값은 일련의 정수로 구성
#     - #### 대상의 값이 같다면 해시 연산에 의한 결과값도 마찬가지로 일치하는 특성이 있다

# %% [markdown]
# - #### 스위프트에서 제공하는 모든 기본 타입은 기본적으로 해시 연산을 할 수 있으므로 집합의 아이템으로 사용하기에 문제가 없다
# #### 만약 스위프트에서 기본으로 제공하는 타입이 아니라 우리가 임의로 만든 타입을 사용하여 집합의 아이템으로 저장하려면??
# - #### 스위프트 표준 라이브러리에서 제공하는 Hashable 프로토콜을 구현해야 한다.
#     - 즉, HashValue라고 불리는 해시값을 만들어 낼 수 있는 기능을 정의해야 한다

# %% [markdown]
# ### 참고
# #### 해시 연산이란?
# - #### 해시 연산은 보통 해시 알고리즘(Hash Algorithm)이라 불린다
#     - #### 임의의 입력된 메세지를 고정 길이의 데이터 크기로 변환해주는 알고리즘
# - #### 해시 알고리즘을 사용하면 아무리 긴 데이터나 아무리 짧은 길이의 데이터라 할지라도 고정 길이의 데이터로 변환할 수 있다
# - #### 해시 연산에서는 서로 다른 값을 연산했을 때 같은 결과값이 나올 가능성이 있으며, 이를 해시 충돌이라고 부른다
#     - 이런 해시 충돌의 가능성이 낮을수록 좋은 해시 알고리즘으로 평가받게 된다.
# - #### 해시 연산의 결과값 길이가 길지 않으면서도 해시 충돌 가능성이 낮아야만 좋은 알고리즘이라고 할 수 있다
# - 많이 알려진 해시 알고리즘에는 MD5, SHA1, SHA256 등이 있다.
# - #### 해시 연산은 아무리 긴 메세지라 할지라도 짧은 일정 길이의 데이터로 변환할 수 있다는 특징이 있다
# - #### 해시 연산은 입력값이 변경될 경우 해시 연산의 결과값도 달라진다는 특징도 있다
#     - #### 이 때문에 데이터의 무결성 검증이나 메시지 인증 등에 사용되는 경우가 많다
# - #### 딕셔너리처럼 해시 연산값을 기준으로 데이터를 정렬하여 저장하는 데에 사용되기도 한다
# - #### 해시 연산값을 이용한 자료 탐색은 현존하는 자료 탐색 기술 중에서 가장 빠른 기술이므로 메모리를 낭비한다는 단점에도 불구하고 많이 사용된다
# - 해시 알고리즘은 연산 처리 과정에서 일접 부분 원본 데이터의 손실이 발생하므로 해시 연산으로 얻은 결과값을 역이용하여 본해의 데이터를 구하는 것은 수학적으로 매우 어려운 일이다.
#     - #### 이 때문에 복호화가 필요 없는 암호화에 많이 사용되기도 한다
# --------------------------------------------------------------------------------------------------------------------------------------------
