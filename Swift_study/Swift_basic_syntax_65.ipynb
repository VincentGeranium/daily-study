# %% [markdown]
# # 구조체와 클래스
# ## 객체지향 스위프트
# ## 프로퍼티(Property)

# %% [markdown]
# ### 클래스와 구조체를 구성하는 요소 중 하나인 Property
# - 우리말로 번역하면 '속성'
# - #### 프로퍼티는 값을 저장하기 위한 목적으로 클래스와 구조체 내에서 정의된 변수나 상수이다
#     - #### 이는 프로퍼티 역활의 일부에 불과하다
# - #### 클래스나 구조체에서 프로퍼티가 하는 정확한 역활은 값을 제공하는 것이다

# %% [markdown]
# ### 값을 제공하는 것과 값을 저장하는 것 사이에 차이가 없다고 생각할 수 있다
# - #### 하지만 굳이 저장이 아니라 제공에 그 목적이 있다고 설명한 것은, 프로퍼티 중 일부는 값을 저장하지는 않지만 값을 제공하는 특성을 가지기 때문이다
# - #### 따라서 프로퍼티의 역활을 단순히 "값을 저장하는 데에 있다"라고 정의해 버리면 안된다

# %% [markdown]
# ### 프로퍼티는 값에 대한 저장 여부를 기준으로 두 가지 종류로 나눌 수 있다
# - #### 1. 저장 프로퍼티
# - #### 2. 연산 프로퍼티
#
# ### 두 프로퍼티의 차이는 다음과 같다
#
# - ### 1.저장 프로퍼티
#     - #### 입력된 값을 저장하거나 저장된 값을 제공하는 역활
#     - #### 상수 및 변수를 사용해서 정의 가능
#     - #### 클래스와 구조체에서는 사용이 가능하지만, 열거형에서는 사용할 수 없다
#
# - ### 2. 연산 프로퍼티
#     - #### 특정 연산을 통해 값을 만들어 제공하는 역활
#     - #### 변수만 사용해서 정의 가능
#     - #### 클래스, 구조체, 열거형 모두에서 사용 가능

# %% [markdown]
# ### 저장 프로퍼티와 연산 프로퍼티는 대체로 클래스나 구조체를 바탕으로 만들어진
# ### 개별 인스턴스에 소속되어 값을 저장하거나 연산 처리하는 역활을 한다
# - #### 따라서 프로퍼티를 사용하려면 인스턴스가 필요하다
# - #### 인스턴스를 생성한 다음 이 인스턴스를 통해서 프로퍼티를 참조하거나 값을 할당해야 한다
# - ### 이렇게 인스턴스에 소속되는 프로퍼티를 "인스턴스 프로퍼티"라고 한다

# %% [markdown]
# ### 예외적으로 일부 프로퍼티는 클래스와 구조체 자체에 소속되어 값을 가지기도 한다
# - #### 이런 프로퍼티들을 "타입 프로퍼티(Type Properies)"라고 한다
# - #### 타입 프로퍼티는 인스턴스를 생성하지 않아도 사용할 수 있다

# %% [markdown]
# ### 프로퍼티의 분류
#
# - ### 1. 역활에 따른 분류
#     - #### 1-1. 저장 프로퍼티(Stored Property)
#     - #### 1-2. 연산 프로퍼타(Computed Property)
#
# - ### 2. 소속에 따른 분류
#     - #### 2-1. 인스턴스 프로퍼티(Instance Property)
#     - #### 2-2. 타입 프로퍼티(Type Property)

# %% [markdown]
# ### 프로퍼티를 작성할 때에는 위치가 중요하다
# - #### 클래스 정의 구문 내부에 작성되어야 하지만, 메소드 내부에 작성되면 안되기 때문이다
# - #### 메소드 내에서도 변수나 상수를 사용하여 값을 저장 할 수 있는데, 이것은 프로퍼티가 아니라 지역 변수에 불과하다
# - #### 따라서 프로퍼티는 클래스의 내부에, 그리고 메소드의 외부에 정의해야 한다

# %% [markdown]
# ### 부가적으로 스위프트에서는 프로퍼티 값을 모니터링하기 위해 "프로퍼티 옵져버(Property Observer)"를 정의
# - #### 사용자가 정의한 특정 액션과 반응하도록 처리할 수 있다
# - #### 프로퍼티 옵저버는 직접 정의한 저장 프로퍼티에 추가할 수 있으며 슈퍼 클래스로부터 상속받은 서브 클래스에서도 추가할 수 있다
