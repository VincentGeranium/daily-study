# %% [markdown]
# # 구조체와 클래스
# ## 객체지향 스위프트
# ## 초기화 구문(Initializer syntax)

# %% [markdown]
# ### 구조체나 클래스는 모두 정의된 내용을 그대로 사용할 수는 없다
# - #### 항상 인스턴스를 생성해서 메모리 공간을 할당받은 다음에 사용해야 한다
#     - ### 이를 "초기화"라고 한다

# %% [markdown]
# ### 초기화 과정에서 가장 중요한 것은 저장 프로퍼티이다
# - #### 모든 저장 프로퍼티는 인스턴스 생성과정에서 초기화되어야 하며, 이를 위해서는 반드시 초기값이 지정되어 있어야 한다
# - #### 모든 저장 프로퍼티에 초기값이 지정되어 있다면 기본 초기화 구문을 사용하여 인스턴스를 생성할 수 있다
#     - #### 지금까지 익히 사용해 왔던 다음 구문이 기본 초기화 구문을 사용하여 인스턴스를 생성한 것이다
#
#     ```
#     Resolution()
#     Video()
#     SUV()
#     Car()
#     Vehicle()
#     ```

# %% [markdown]
# ### 기본 초기화 구문은 인스턴스를 생성하는 본연의 기능 외에 프로퍼티와 관련하여 내부적으로 아무 것도 처리하지 않는다
# - #### 모든 저장 프로퍼티의 초기값이 이미 지정되어 있기 때문이다

# %% [markdown]
# ### 하지만 아래의 초기화 구문을 보자
#
# ```
# Point(x: 10.5, y: 12.0)
# ```
#
# - 앞서 예제에서 다루어 보았던 Point 구조체의 초기화 구문

# %% [markdown]
# ### 이 초기화 구문은 인스턴스를 생성하는 기능 외에도, 구조체 내부에 정의된 x, y 프로퍼티의 초기값을 입력받은 인자값으로 초기화하는 역활까지 담당한다
# - #### 구조체 내부에 선언된 모든 저장 프로퍼티를 일괄로 외부의 값으로 초기화할 수 있는 이 구문을 멤버와이즈 초기화 구문(memberwise initializer)이라고 한다

# %% [markdown]
# ### 그런데 x, y 두 프로퍼티 중 아래와 같이 일부 프로퍼티만 인자값으로 초기화하고
# ### 나머지 프로퍼티는 내부에 정의된 초기값을 그대로 사용하고 싶을 때에는 어떻게 해야 할까?
#
# ```
# Point(x: 10.5)
# ```
#
# - #### 이런 형식의 초기화 구문은 구조체에서 제공되지 않는다
# - #### 미리 약속된 형태가 아니기 때문이다
#
# ### 따라서 일부 프로퍼티만 외부값으로 초기화하려면 원하는 매개변수 형태를 가진 초기화 구문을 직접 정의하여 사용해야 한다

# %% [markdown]
# ### 클래스의 경우도 마찬가지이다
# - #### 멤버와이즈 초기화 구문(Memberwise initializer)은 구조체에서만 제공되는 기능이므로, 클래스의 경우에는 멤버와이즈 초기화 구문이 제공되지 않는다
# - #### 따라서 멤버와이즈 초기화 구문을 사용하려면, 즉 다시 말해 외부에서 프로퍼티의 초기값을 지정해 주고 싶다면 형식과 내용을 직접 정의해서 사용해야 한다

# %% [markdown]
# ### 이처럼, 기본 구문 이외의 형식으로 원하는 인자값을 전달하여 저장 프로퍼티를 초기화하려면 반드시 구조체나 클래스 내부에 그에 맞는 형태와 할 일을 미리 정의해 두어야 한다
# - #### 이때 사용되는 것이 바로 초기화 메소드이다
# - #### 초기화 메소드는 형태나 문법은 다를지라도 다른 객체 지향 언어에서도 찾아볼 수 있는 개념이다
#     - #### 이 개념은 인스턴스가 생성될 때의 형식과 할 일을 정의한다고 하여 생성자(Constructor)라고 부르기도 한다
