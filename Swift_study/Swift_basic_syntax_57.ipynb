# %% [markdown]
# # 구조체와 클래스
# ## 객체지향 스위프트

# %% [markdown]
# ### 개념적으로 구조체와 클래스는 하나의 큰 코드 블록이다
# - ### 이 안에 변수나 상수를 넣어 값을 저장할 수도 있고, 함수를 넣어서 기능을 정의할 수도 있다
#     - #### 값을 저장할 수는 없지만 특정 기능을 실행할 수 있는 함수의 특성
#     - #### 값을 저장할 수 있지만 혼자서 특정 기능을 실행할 수는 없는 변수 상수의 특성
#         - #### 위 두 가지 특성을 모아놓았다고 이해하면 편리하다
#
# ### 이런 특성 때문에 클래스와 구조체는 다른 종류의 객체에 의존하지 않고도 자체적으로 값을 저장하거나 함수적인 기능을 구현할 수 있다

# %% [markdown]
# ### 독자적인 프로세스 수행 능력 덕분에 매우 강력한 사용성을 지니는 이들 객체는 스위프트 언어적으로 유연성을 가질 수 있게 해주는 근간을 이룬다
# - #### 여기서 말하는 유연성이란 코드를 떼어서 다른 곳으로 옮기거나 새로운 코드를 추가하기가 쉽다는 뜻
#     - #### 의존성의 반대 개념
#     - #### 의존성이 강한 코드는 분리할 때 떼어 내어야 하는 부분이 많아서 힘들다

# %% [markdown]
# ### 구조체와 클래스 내에서 정의된 변수와 상수, 그리고 함수는 부르는 명칭이 일반의 그것과는 다르다
#
# - #### 똑같은 변수와 상수라도 구조체와 클래스 내부에서 정의되면 프로퍼티(Properties)라는 이름을 가진다
#     - #### 속성 변수 또는 상수라고 불리기도 한다
# - #### 함수도 마찬가지이다. 구조체와 클래스 내부에서 정의된 함수는 Function이 아니라 메소드(Method)라고 불린다
# - #### 이는 변수와 상수, 함수가 구조체나 클래스 안에 들어가면서 특별한 성격을 갖기 때문이다

# %% [markdown]
# ### Properties 와 Method를 합해서 "구조체나 클래스의 Member"라고 표현한다
# - #### 이는 프로퍼티와 메소드가 구조체나 클래스를 이루는 핵심 요소이기 때문이다
#     - #### 멤버 속성, 멤버 변수, 멤버 메소드 등 다양한 용어가 사용되는데, 이는 모두 이 멤버라는 표현과 결합된 프로퍼티나 메소드를 의미하는 것으로 생각하면 된다

# %% [markdown]
# ### 스위프트는 기본적으로 객체지향 언어이다.
# - #### 필요한 기능을 객체로 구현하여 사용한다는 것이 객체지향 언어의 핵심이다
# - #### 이때 객체를 만들어내는 주요 대상이 바로 구조체와 클래스 이다
# - #### 구조체와 클래스는 스위프트가 객체지향이기 위한 근간을 이루는 매우 중요한 핵심 객체이다
# - #### 구조체와 클래스는 iOS에서 실행되는 애플리케이션을 만들 때에도 중심 역활을 하는 중요한 개념이다
