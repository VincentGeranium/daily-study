# %% [markdown]
# # 모듈

# %% [markdown]
# ## 모듈 만들고 불러 보기

# %%
#mod1.py
def sum(a, b):
    return a + b

# %% [markdown]
# ![mk_module.png](attachment:mk_module.png)

# %% [markdown]
# #### 모듈을 불러오기 위해 import mod1 입력
# #### mod1.py 파일에 있는 sum 함수를 이용하기 위해 mod1.sum입력

# %% [markdown]
# #### import 사용 방법
# - import $모듈이름$
# - 여기서 모듈 이름은 mod1.py에서 .py 확장자를 제거한 mod1만을 가리킨다

# %% [markdown]
# ## 모듈에 함수 추가

# %%
def sum(a, b):
    return a + b

def safe_sum(a, b):
    if type(a)!=type(b): #객체 a와 객체 b의 자료형이 같지 않으면
        print("더할수 있는 것이 아닙니다.") #메세지 출력
        return #메세지 출력
    else:#객체 a와 객체 b의 자료형이 같다면
        result = sum(a,b)#두 객체를 더한다
        return result

# %% [markdown]
# ## 모듈 실행

# %% [markdown]
# ![module2.png](attachment:module2.png)
